# %%
# !pip install brewer2mpl 

import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings; warnings.filterwarnings(action='once')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
large = 22; med = 16; small = 12
params = {'axes.titlesize': large,
          'legend.fontsize': med,
          'figure.figsize': (16, 10),
          'axes.labelsize': med,
          'axes.titlesize': med,
          'xtick.labelsize': med,
          'ytick.labelsize': med,
          'figure.titlesize': large}
plt.rcParams.update(params)
plt.style.use('seaborn-whitegrid')
sns.set_style("white")
# %matplotlib inline

 #Version */
print(mpl.__version__)  
print(sns.__version__)
# Out:
# 3.2.2
# 0.11.2

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-16569473-1f2b-4b9a-a496-aa440066b40e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-16569473-1f2b-4b9a-a496-aa440066b40e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving swiid.csv to swiid.csv

# %%
swiid= pd.read_csv('swiid.csv')

# %%
swiid.shape
# Out:
# (5625, 10)

# %%
swiid.sample(5)
# Out:
#         country  year  gini_disp  gini_disp_se  gini_mkt  gini_mkt_se  \
# 3744     Panama  2015       46.5           0.9      50.8          1.4
# 5412    Uruguay  2012       36.5           0.5      46.5          0.6
# 237   Australia  2015       32.4           1.0      48.0          1.3
# 763      Canada  1972       30.7           0.8      40.6          0.9
# 3977   Portugal  2016       33.0           1.3      51.3          2.3
#
#       abs_red  abs_red_se  rel_red  rel_red_se
# 3744      4.3         1.7      8.5         2.2
# 5412     10.0         0.8     21.5         1.0
# 237      15.6         1.6     32.5         2.1
# 763       NaN         NaN      NaN         NaN
# 3977     18.3         2.6     35.7         3.5

# %% [markdown]
# ini index < 0.2 represents perfect income equality, 0.2–0.3 relative equality, 0.3–0.4 adequate equality, 0.4–0.5 big income gap, and above 0.5 represents severe income gap. Therefore, the warning level of Gini index is 0.4.
#
#
# 'perfect equality', 'relative equality', 'adequate equality', 'innequality', 'perfect innequality'
#
# https://www.researchgate.net/post/What-does-the-value-of-the-Gini-coefficient-02876-mean#:~:text=Gini%20index%20%3C%200.2%20represents%20perfect,0.5%20represents%20severe%20income%20gap.

# %%
#alldata = data.merge(gap, how ='inner', on=['country', 'year'])

# %%
! pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.8 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 9.8 MB 30.2 MB/s
# ...
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.12.2
#     Uninstalling statsmodels-0.12.2:
#       Successfully uninstalled statsmodels-0.12.2
# ...
# /usr/local/lib/python3.7/dist-packages/google/colab/_pip.py:83: ResourceWarning: unclosed file <_io.TextIOWrapper name='/usr/local/lib/python3.7/dist-packages/pmdarima-2.0.1.dist-info/top_level.txt' mode='r' encoding='UTF-8'>
#   for line in open(toplevel):
# ...
# /usr/local/lib/python3.7/dist-packages/google/colab/_pip.py:83: ResourceWarning: unclosed file <_io.TextIOWrapper name='/usr/local/lib/python3.7/dist-packages/statsmodels-0.13.2.dist-info/top_level.txt' mode='r' encoding='UTF-8'>
#   for line in open(toplevel):
# ...

# %%
data = swiid.drop(['gini_disp_se', 'gini_mkt',
       'gini_mkt_se', 'abs_red', 'abs_red_se', 'rel_red', 'rel_red_se'], axis =1)

# %%
cat = pd.cut(data.gini_disp, bins = [0, 26, 36, 46, 56, 65], labels = ['perfect equality', 'relative equality', 'adequate equality', 'innequality', 'perfect innequality'])

# %%
data.insert(3, 'Gini_g_level', cat)

# %%
data.sample(70)
# Out:
#           country  year  gini_disp       Gini_g_level
# 5128      Tunisia  2015       38.9  adequate equality
# 1977     Honduras  2007       51.1        innequality
# 4939     Tanzania  2007       43.8  adequate equality
# 2590        Kenya  2009       46.5        innequality
# 155     Argentina  2015       37.7  adequate equality
# ...           ...   ...        ...                ...
# 4516        Spain  2013       33.4  relative equality
# 3614       Norway  2017       25.5   perfect equality
# 1547      Finland  1994       22.1   perfect equality
# 3459  New Zealand  1982       26.9  relative equality
# 2281      Ireland  1979       30.3  relative equality
#
# [70 rows x 4 columns]

# %% [markdown]
# 'South Africa',
# 'Namibia',
# 'Suriname',
# Zambia
# Sao Tome and Principe -
# Central African Republic -
# Eswatini -
# Mozambique -
# Brazil -
# Belize -
# Botswana
# Belize
# Colombia
# Angola
# Saint Lucia
# Guinea Bissau
# Zimbabwe
#
#
#
# South Africa	63.00	2014
# 2	Namibia	59.10	2015
# 3	Suriname	57.90	1999
# 4	Zambia	57.10	2015
# 5	Central African Republic	56.20	2008
# 6	Eswatini	54.60	2016
# 7	Colombia	54.20	2020
# 8	Mozambique	54.00	2014
# 9	Botswana	53.30	2015
# 9	Belize	53.30	1999
# 11	Angola	51.30	2018
# 12	St. Lucia	51.20	2016
# 13	Zimbabwe	50.30	2019
# 14	Panama	49.80	2019
# 15	Costa Rica

# %%
#https://sparkbyexamples.com/pandas/pandas-filter-rows-by-conditions/

# %%
# By using lambda function
#print(data.apply(lambda row: row[data['gini group level'].isin(['Spark','PySpark'])]))

# %% [markdown]
# 'Slovenia',
# 'Czech Republic',
# 'Slovakia',
# 'Belarus',
# 'Moldova',
# 'United Arab Emirates',
# 'Iceland',
# 'Azerbaijan',
# 'Ukraine',
# 'Belgium'

# %% [markdown]
# option= []

# %%
#https://www.absentdata.com/pandas/pandas-cut-continuous-to-categorical/

# %%
import seaborn as sns

# %% [markdown]
# #USA

# %%
#south_africa =data1[data1['country'] == 'South Africa']

# %%
usa = data[data['country']=='United States']

# %%
usa.shape
# Out:
# (57, 4)

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(15, 6))
us = usa
#d = albania[albania['value']==2]
sns.lineplot(us['year'], us['gini_disp'])

ax.set_title('USA Gini over time', fontsize = 20, loc='center', fontdict=dict(weight='bold'))
ax.set_xlabel('Year', fontsize = 16, fontdict=dict(weight='bold'))
ax.set_ylabel('Wealth Innequlaity Indicator(GINI)', fontsize = 16, fontdict=dict(weight='bold'))
plt.tick_params(axis='y', which='major', labelsize=16)
plt.tick_params(axis='x', which='major', labelsize=16)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#import torch.nn as nn
#import torch.optim as optim
import datetime as dt
#import torch
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf 
from statsmodels.tsa.seasonal import seasonal_decompose 
from pmdarima import auto_arima                        
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse
import warnings
warnings.filterwarnings("ignore")
#import matplotlib.pyplot as plt
#import matplotlib as mpl

# %%
usa = usa.set_index("year")

# %%
fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(16,6), dpi= 80)
plot_acf(usa.gini_disp.tolist(), ax=ax1, lags=56)
plot_pacf(usa.gini_disp.tolist(), ax=ax2, lags=26)

 #/* Decorate */
#/* lighten the borders */
ax1.spines["top"].set_alpha(.3); ax2.spines["top"].set_alpha(.3)
ax1.spines["bottom"].set_alpha(.3); ax2.spines["bottom"].set_alpha(.3)
ax1.spines["right"].set_alpha(.3); ax2.spines["right"].set_alpha(.3)
ax1.spines["left"].set_alpha(.3); ax2.spines["left"].set_alpha(.3)

#/* font size of tick labels */
ax1.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)
plt.show()

# %% [markdown]
# ##CHINA

# %%
china =data[data['country'] == 'China']

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(15, 6))
c = china
#d = albania[albania['value']==2]
sns.lineplot(c['year'], c['gini_disp'])

ax.set_title('China Gini over time', fontsize = 20, loc='center', fontdict=dict(weight='bold'))
ax.set_xlabel('Year', fontsize = 16, fontdict=dict(weight='bold'))
ax.set_ylabel('Wealth Innequlaity Indicator(GINI)', fontsize = 16, fontdict=dict(weight='bold'))
plt.tick_params(axis='y', which='major', labelsize=16)
plt.tick_params(axis='x', which='major', labelsize=16)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(16,6), dpi= 80)
plot_acf(china.gini_disp.tolist(), ax=ax1, lags=38)
plot_pacf(china.gini_disp.tolist(), ax=ax2, lags=19)

 #/* Decorate */
#/* lighten the borders */
ax1.spines["top"].set_alpha(.3); ax2.spines["top"].set_alpha(.3)
ax1.spines["bottom"].set_alpha(.3); ax2.spines["bottom"].set_alpha(.3)
ax1.spines["right"].set_alpha(.3); ax2.spines["right"].set_alpha(.3)
ax1.spines["left"].set_alpha(.3); ax2.spines["left"].set_alpha(.3)

#/* font size of tick labels */
ax1.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
dftest = adfuller(china.gini_disp, autolag = 'AIC')
print("1. ADF : ",dftest[0])
print("2. P-Value : ", dftest[1])
print("3. Num Of Lags : ", dftest[2])
print("4. Num Of Observations Used For ADF Regression and Critical Values Calculation :", dftest[3])
print("5. Critical Values :")
for key, val in dftest[4].items():
    print("\t",key, ": ", val)
# Out:
# 1. ADF :  -1.7630548309555902
# 2. P-Value :  0.39895198210341654
# 3. Num Of Lags :  1
# 4. Num Of Observations Used For ADF Regression and Critical Values Calculation : 38
# 5. Critical Values :
# 	 1% :  -3.6155091011809297
# 	 5% :  -2.941262357486514
# 	 10% :  -2.6091995013850418

# %%
from statsmodels.tsa.stattools import adfuller
dftest = adfuller(usa.gini_disp, autolag = 'AIC')
print("1. ADF : ",dftest[0])
print("2. P-Value : ", dftest[1])
print("3. Num Of Lags : ", dftest[2])
print("4. Num Of Observations Used For ADF Regression and Critical Values Calculation :", dftest[3])
print("5. Critical Values :")
for key, val in dftest[4].items():
    print("\t",key, ": ", val)
# Out:
# 1. ADF :  0.8634791417940741
# 2. P-Value :  0.9925947221193557
# 3. Num Of Lags :  0
# 4. Num Of Observations Used For ADF Regression and Critical Values Calculation : 56
# 5. Critical Values :
# 	 1% :  -3.552928203580539
# 	 5% :  -2.9147306250000002
# 	 10% :  -2.595137155612245

# %%
powered_transform = pd.DataFrame(usa.gini_disp.apply(lambda x :  x ** 0.5))
rolling_mean = powered_transform.rolling(window = 12).mean()
diff = rolling_mean - rolling_mean.shift(1)
ax1 = plt.subplot()
diff.plot(title='USA GINI Index after power transformed rolling mean & differencing');
ax2 = plt.subplot()
usa.plot(title=' USA GINI Index original');

# %%
powered_transform = pd.DataFrame(usa.gini_disp.apply(lambda x :  x ** 0.5))
rolling_mean = powered_transform.rolling(window = 12).mean()
diff = rolling_mean - rolling_mean.shift(1)
ax1 = plt.subplot()
diff.plot(title='USA GINI Index after power transformed rolling mean & differencing');
ax2 = plt.subplot()
usa.plot(title=' USA GINI Index original');

# %%
usa= usa.drop(['country', 'Gini_g_level'], axis =1)

# %%
powered_transform =  pd.DataFrame(usa.gini_disp.apply(lambda x : x ** 0.5))
powered_transform_diff_us = powered_transform - powered_transform.shift()
ax1 = plt.subplot()
powered_transform_diff_us.plot(title='USA after power transformed & differencing');
ax2 = plt.subplot()
usa.plot(title='original');

# %%
china = china.set_index("year")

# %%
test_us = adfuller(powered_transform_diff_us.dropna().gini_disp)
print("p-value :", test_us[1])
# Out:
# p-value : 7.928294057742943e-06

# %%
powered_transform = pd.DataFrame(china.gini_disp.apply(lambda x : x ** 0.5))
powered_transform_diff_ch = powered_transform - powered_transform.shift()
ax1 = plt.subplot()
powered_transform_diff_ch.plot(title='China GINI Index original after power transformed & differencing');
ax2 = plt.subplot()
china.plot(title=' China GINI Index original');

# %%
test_ch= adfuller(powered_transform_diff_ch.dropna().gini_disp)
print("p-value :", test_ch[1])
# Out:
# p-value : 0.37186357663446656

# %%
test = adfuller(diff.dropna().gini_disp)
print("p-value :", test[1])
# Out:
# p-value : 0.29114695970731963

# %%
logged_transform = pd.DataFrame(china.gini_disp.apply(lambda x : np.log(x)))
rolling_mean = logged_transform.rolling(window = 12).mean()
diff_ch = rolling_mean - rolling_mean.shift(1)
ax1 = plt.subplot()
diff.plot(title='after log transformed rolling mean & differencing');
ax2 = plt.subplot()
china.plot(title='original');

# %%
powered_transform = pd.DataFrame(usa.gini_disp.apply(lambda x :  x ** 0.5))
rolling_mean = powered_transform.rolling(window = 12).mean()
diff = rolling_mean - rolling_mean.shift(1)
ax1 = plt.subplot()
diff.plot(title='after power transformed rolling mean & differencing');
ax2 = plt.subplot()
data.plot(title='original');

# %%
china.columns
# Out:
# Index(['country', 'gini_disp', 'Gini_g_level'], dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
belgium =data[data['country'] == 'Belgium']

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(15, 6))
b=belgium
sns.lineplot(b['year'], b['gini_disp'])

ax.set_title('Belgium Gini over time', fontsize = 20, loc='center', fontdict=dict(weight='bold'))
ax.set_xlabel('Year', fontsize = 16, fontdict=dict(weight='bold'))
ax.set_ylabel('Wealth Innequlaity Indicator(GINI)', fontsize = 16, fontdict=dict(weight='bold'))
plt.tick_params(axis='y', which='major', labelsize=16)
plt.tick_params(axis='x', which='major', labelsize=16)

# %%
belgium.tail()
# Out:
#      country  year  gini_disp       Gini_g_level
# 468  Belgium  2013       26.1  relative equality
# 469  Belgium  2014       26.1  relative equality
# 470  Belgium  2015       26.0   perfect equality
# 471  Belgium  2016       26.0   perfect equality
# 472  Belgium  2017       25.8   perfect equality

# %%
southAfrica = data[data['country'] == 'South Africa']

# %%
southAfrica.sample(2)
# Out:
#            country  year  gini_disp         Gini_g_level
# 4436  South Africa  1987       58.6  perfect innequality
# 4447  South Africa  1998       58.9  perfect innequality

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(15, 6))
s = southAfrica
#d = albania[albania['value']==2]
sns.lineplot(s['year'], s['gini_disp'])

ax.set_title('South Africa Gini over time', fontsize = 20, loc='center', fontdict=dict(weight='bold'))
ax.set_xlabel('Year', fontsize = 16, fontdict=dict(weight='bold'))
ax.set_ylabel('Wealth Innequlaity Indicator(GINI)', fontsize = 16, fontdict=dict(weight='bold'))
plt.tick_params(axis='y', which='major', labelsize=16)
plt.tick_params(axis='x', which='major', labelsize=16)

# %%
#%matplotlib inline
china.index.freq = 'MS'
ax = china['gini_disp'].plot(figsize = (16,5), title = "China Gini Index")
ax.set(xlabel='year', ylabel='Gini Index');
plt.show()

# %%
plt.figure(figsize=( 16,5))
ax = plt.plot(china.index, china['gini_disp'], linestyle = '-')
plt.xlabel('Year')
plt.ylabel('Gini Index')
plt.title("China Gini Index")
plt.show();

# %%
china.shape
# Out:
# (40, 3)

# %% [markdown]
# https://medium.com/@cdabakoglu/time-series-forecasting-arima-lstm-prophet-with-python-e73a750a9887
#
# https://hands-on.cloud/using-the-arima-model-and-python-for-time-series-forecasting/
# https://medium.com/swlh/temperature-forecasting-with-arima-model-in-python-427b2d3bcb53?sk=ff83ea42d7ca5eee874fc4f4be219604

# %%
china.tail()
# Out:
#      country  gini_disp       Gini_g_level
# year
# 2013   China       40.8  adequate equality
# 2014   China       40.8  adequate equality
# 2015   China       40.8  adequate equality
# 2016   China       40.8  adequate equality
# 2017   China       40.9  adequate equality

# %%
china= china.drop(['country', 'Gini_g_level'], axis =1)

# %%
china.sample(5)
# Out:
#       gini_disp
# year
# 2017       40.9
# 1981       27.7
# 2001       39.7
# 1988       30.7
# 1985       28.1

# %%
#USA
test_size_us = 12

train_data_us = usa[:-test_size_us]
test_data_us = usa[-test_size_us:]

# %%
#USA

powered_transform_diff_us
test_size_us = 12

train_data_us_1 = powered_transform_diff_us[:-test_size_us]
test_data_us_1 = powered_transform_diff_us[-test_size_us:]

# %%
powered_transform_diff_us
test_size_us = 12

train_data_us_2 = powered_transform_diff_us[:-test_size_us]
test_data_us_2 = powered_transform_diff_us[-test_size_us:]

# %%
#CHINA
test_size_c_1 = 9
train_data_c_1 = powered_transform_diff_ch[:-test_size_c_1]
test_data_c_1 = powered_transform_diff_ch[-test_size_c_1:]

# %%
#CHINA
test_size_c = 9

train_data_c = china[:-test_size_c]
test_data_c = china[-test_size_c:]

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
arima_model_c_1 = SARIMAX(train_data_c_1['gini_disp'], order = (1,1,1), seasonal_order = (4,0,3,12))
arima_result_c_1 = arima_model_c_1.fit()
arima_result_c_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                          SARIMAX Results
# ...
# Dep. Variable:                                  gini_disp   No. Observations:                   31
# Model:             SARIMAX(1, 1, 1)x(4, 0, [1, 2, 3], 12)   Log Likelihood                  67.170
# Date:                                    Thu, 01 Sep 2022   AIC                           -114.340
# Time:                                            12:37:06   BIC                           -100.328
# Sample:                                                 0   HQIC                          -109.858
#                                                      - 31
# Covariance Type:                                      opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3111      1.064      0.292      0.770      -1.774       2.396
# ...

# %%
arima_model_c = SARIMAX(train_data_c['gini_disp'], order = (1,1,1), seasonal_order = (4,0,3,12))
arima_result_c = arima_model_c.fit()
arima_result_c.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                          SARIMAX Results
# ...
# Dep. Variable:                                  gini_disp   No. Observations:                   31
# Model:             SARIMAX(1, 1, 1)x(4, 0, [1, 2, 3], 12)   Log Likelihood                   3.709
# Date:                                    Thu, 01 Sep 2022   AIC                             12.581
# Time:                                            12:37:16   BIC                             26.593
# Sample:                                                 0   HQIC                            17.064
#                                                      - 31
# Covariance Type:                                      opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9110      0.167      5.466      0.000       0.584       1.238
# ...

# %%
start = len(train_data_c)
end=len(train_data_c)+len(test_data_c)-1


arima_pred_c = arima_result_c.predict(start = start, end = end, typ="levels").rename("ARIMA Predictions", )
arima_pred_c.index=china.index[start:end +1 ] 

arima_pred_c
# Out:
# year
# 2009    42.834743
# 2010    42.526994
# 2011    42.170137
# 2012    41.647138
# 2013    41.291201
# 2014    40.985207
# 2015    40.760428
# 2016    40.420876
# 2017    39.935355
# Name: ARIMA Predictions, dtype: float64

# %%
test_data_c['gini_disp'].plot(figsize = (16,5), legend=True)
arima_pred_c.plot(legend = True);

# %%
start = len(train_data_c_1)
end=len(train_data_c_1)+len(test_data_c_1)-1


arima_pred_c_1 = arima_result_c_1.predict(start = start, end = end, typ="levels").rename("ARIMA Predictions", )
arima_pred_c_1.index=powered_transform_diff_ch.index[start:end +1 ] 

arima_pred_c_1
# Out:
# year
# 2009   -0.004817
# 2010   -0.021595
# 2011   -0.024551
# 2012   -0.035756
# 2013   -0.023474
# 2014   -0.019676
# 2015   -0.011471
# 2016   -0.020804
# 2017   -0.016123
# Name: ARIMA Predictions, dtype: float64

# %%
test_data_c_1['gini_disp'].plot(figsize = (16,5), legend=True)
arima_pred_c_1.plot(legend = True);

# %%
arima_model = SARIMAX(train_data_c['gini_disp'], order = (1,1,1), seasonal_order = (4,0,3,12))
arima_result = arima_model.fit()
arima_result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                          SARIMAX Results
# ...
# Dep. Variable:                                  gini_disp   No. Observations:                   31
# Model:             SARIMAX(1, 1, 1)x(4, 0, [1, 2, 3], 12)   Log Likelihood                   3.709
# Date:                                    Thu, 01 Sep 2022   AIC                             12.581
# Time:                                            12:37:28   BIC                             26.593
# Sample:                                                 0   HQIC                            17.064
#                                                      - 31
# Covariance Type:                                      opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9110      0.167      5.466      0.000       0.584       1.238
# ...

# %%
arima_model_c_1 = SARIMAX(train_data_c_1['gini_disp'], order = (1,1,1), seasonal_order = (4,0,3,12))
arima_result_c_1 = arima_model_c_1.fit()
arima_result_c_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                          SARIMAX Results
# ...
# Dep. Variable:                                  gini_disp   No. Observations:                   31
# Model:             SARIMAX(1, 1, 1)x(4, 0, [1, 2, 3], 12)   Log Likelihood                  67.170
# Date:                                    Thu, 01 Sep 2022   AIC                           -114.340
# Time:                                            12:37:35   BIC                           -100.328
# Sample:                                                 0   HQIC                          -109.858
#                                                      - 31
# Covariance Type:                                      opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3111      1.064      0.292      0.770      -1.774       2.396
# ...

# %%
arima_model_c_2 = SARIMAX(train_data_c_1['gini_disp'], order = (2,2,2), seasonal_order = (4,0,3,12))
arima_result_c_2 = arima_model_c_2.fit()
arima_result_c_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                          SARIMAX Results
# ...
# Dep. Variable:                                  gini_disp   No. Observations:                   31
# Model:             SARIMAX(2, 2, 2)x(4, 0, [1, 2, 3], 12)   Log Likelihood                  63.280
# Date:                                    Thu, 01 Sep 2022   AIC                           -102.560
# Time:                                            12:37:41   BIC                            -86.152
# Sample:                                                 0   HQIC                           -97.421
#                                                      - 31
# Covariance Type:                                      opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6244      2.106     -0.296      0.767      -4.752       3.504
# ...

# %%
arima_model_usa = SARIMAX(train_data_us['gini_disp'], order = (1,1,1), seasonal_order = (4,0,3,12))
arima_result_usa = arima_model_usa.fit()
arima_result_usa.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                          SARIMAX Results
# ...
# Dep. Variable:                                  gini_disp   No. Observations:                   45
# Model:             SARIMAX(1, 1, 1)x(4, 0, [1, 2, 3], 12)   Log Likelihood                   8.595
# Date:                                    Thu, 01 Sep 2022   AIC                              2.811
# Time:                                            12:37:46   BIC                             20.653
# Sample:                                                 0   HQIC                             9.427
#                                                      - 45
# Covariance Type:                                      opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9627      0.274      3.514      0.000       0.426       1.500
# ...

# %%
arima_model_usa_1 = SARIMAX(train_data_us_1['gini_disp'], order = (1,1,1), seasonal_order = (4,0,3,12))
arima_result_usa_1 = arima_model_usa_1.fit()
arima_result_usa_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                          SARIMAX Results
# ...
# Dep. Variable:                                  gini_disp   No. Observations:                   45
# Model:             SARIMAX(1, 1, 1)x(4, 0, [1, 2, 3], 12)   Log Likelihood                 104.203
# Date:                                    Thu, 01 Sep 2022   AIC                           -188.407
# Time:                                            12:37:51   BIC                           -170.565
# Sample:                                                 0   HQIC                          -181.790
#                                                      - 45
# Covariance Type:                                      opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0519      0.294     -0.177      0.860      -0.627       0.524
# ...

# %%
start = len(train_data_us)
end=len(train_data_us)+len(test_data_us)-1


arima_pred_usa = arima_result_usa.predict(start = start, end = end, typ="levels").rename("ARIMA Predictions", )
arima_pred_usa.index=powered_transform_diff_us.index[start:end +1 ] 

arima_pred_usa
# Out:
# year
# 2006    36.911812
# 2007    36.736575
# 2008    36.746886
# 2009    36.774263
# 2010    36.714941
# 2011    36.767334
# 2012    36.902902
# 2013    36.874133
# 2014    36.971314
# 2015    37.068027
# 2016    37.126691
# 2017    36.756889
# Name: ARIMA Predictions, dtype: float64

# %%
start = len(train_data_us_1)
end=len(train_data_us_1)+len(test_data_us_1)-1


arima_pred_usa_1 = arima_result_usa_1.predict(start = start, end = end, typ="levels").rename("ARIMA Predictions", )
arima_pred_usa_1.index=powered_transform_diff_us.index[start:end +1 ] 

arima_pred_usa_1
# Out:
# year
# 2006    0.009145
# 2007   -0.015517
# 2008    0.001237
# 2009    0.002802
# 2010   -0.010264
# 2011    0.016510
# 2012    0.000851
# 2013    0.005052
# 2014    0.003125
# 2015    0.010394
# 2016   -0.010348
# 2017   -0.018633
# Name: ARIMA Predictions, dtype: float64

# %%
#start = len(train_data_us_2)
#end=len(train_data_us_1)+len(test_data_us_2)-1


#arima_pred_usa_2 = arima_result_usa_2.predict(start = start, end = end, typ="levels").rename("ARIMA Predictions", )
#arima_pred_usa_2.index=powered_transform_diff_us.index[start:end +1 ] 

#arima_pred_usa_2

# %%
test_data_us['gini_disp'].plot(figsize = (16,5), legend=True)
arima_pred_usa.plot(legend = True);

# %%
test_data_us_1['gini_disp'].plot(figsize = (16,5), legend=True)
arima_pred_usa_1.plot(legend = True);

# %%
#test_data_us_2['gini_disp'].plot(figsize = (16,5), legend=True)
#arima_pred_usa_2.plot(legend = True);

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
test_data_c['gini_disp'].mean()
rmse=sqrt(mean_squared_error(arima_pred_c,test_data_c['gini_disp']))
print(rmse)
# Out:
# 0.4176834719361118

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
test_data_c_1['gini_disp'].mean()
rmse=sqrt(mean_squared_error(arima_pred_c_1,test_data_c_1['gini_disp']))
print(rmse)
# Out:
# 0.02428950582699103

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
test_data_us['gini_disp'].mean()
rmse_usa=sqrt(mean_squared_error(arima_pred_usa,test_data_us['gini_disp']))
print(rmse_usa)
# Out:
# 0.8166258403771128

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
test_data_us_1['gini_disp'].mean()
rmse_usa_1=sqrt(mean_squared_error(arima_pred_usa_1,test_data_us_1['gini_disp']))
print(rmse_usa_1)
# Out:
# 0.018084925774166247
